# %%
import tensorflow as tf
print("Num GPUs Available: ", len(tf.config.experimental.list_physical_devices('GPU')))
physical_devices = tf.config.experimental.list_physical_devices('GPU')
tf.config.experimental.set_memory_growth(physical_devices[0], True)
# Out:
# Num GPUs Available:  1

# %%
from keras.models import load_model
from keras.preprocessing import image
import numpy as np
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline
from PIL import Image
# Out:
# Using TensorFlow backend.

# %%
model = load_model('fruit_classifier_multiple.h5')

# %%
FRUITS = ['Apple Braeburn', 'Apricot', 'Avocado', 'Avocado Ripe', 'Banana', 'Banana Red', 'Cactus Fruit', 'Cantaloupe 1', 'Cantaloupe 2', 'Carambula', 'Cherry 1', 'Cherry 2']

# %%
def classifier(path):
    raw_img = image.load_img(path, target_size=(100,100))
    raw_img = image.img_to_array(raw_img)
    raw_img = np.expand_dims(raw_img, axis = 0)
    raw_img = raw_img/255
    prediction1 = model.predict_classes(raw_img)
    #prediction = prediction1[0][0]
    #print(prediction1[0])
    plt.imshow(cv2.imread(path))
    print(FRUITS[prediction1[0]])

# %%
classifier('unknown/img2.jpg')
# Out:
# Banana
